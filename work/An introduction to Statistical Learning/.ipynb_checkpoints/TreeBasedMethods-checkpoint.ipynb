# %%
!install.packages('ISLR')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# Error in !install.packages("ISLR"): invalid argument type
# Traceback:

# %%
library(ISLR)
library(MASS)

# %%
library(randomForest)

# %% [markdown]
# # Tree-Based Methods

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### Regression Trees

# %% [markdown]
# ![Regression Tree](regression_tree_algo.png "Regression Tree")

# %% [markdown]
# For each value of $\alpha$ thre corresponds a subtree $T \subset T_0$ such that
#
# $$
# \sum_{m=1}^{|T|}\sum_{i:x_i \in R_m} (y_i - \hat{y}_{R_m})^2 + \alpha|T|
# $$

# %% [markdown]
# ### Classification Trees

# %% [markdown]
# ## Bagging, Random Forests, Boosting

# %%
set.seed(1)
train = sample(1:nrow(Boston), nrow(Boston)/2)
bag.boston = randomForest(medv~., data = Boston, subset = train, mtry = 13, importance = TRUE)
bag.boston
# Out:
# Call:
#  randomForest(formula = medv ~ ., data = Boston, mtry = 13, importance = TRUE,      subset = train)
#                Type of random forest: regression
#                      Number of trees: 500
# No. of variables tried at each split: 13
#
#           Mean of squared residuals: 11.33119
#                     % Var explained: 85.26

# %%
yhat.bag = predict(bag.boston, newdata = Boston[-train,])
boston.test=Boston [-train ," medv"]
plot(yhat.bag, boston.test)
abline(0,1)
mean((yhat.bag - boston.test)^2)
# Out:
# [1] NaN
# plot without title

# %%
bag.boston = randomForest(medv~., data = Boston, subset = train, mtry = 13, ntree = 25)
yhat.bag = predict(bag.boston, newdata = Boston[-train,])
boston.test=Boston [-train ," medv"]
plot(yhat.bag, boston.test)
mean((yhat.bag - boston.test)^2)
# Out:
# [1] NaN
# plot without title
